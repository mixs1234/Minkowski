# %%
import ipywidgets as widgets
from matplotlib.figure import Figure
import matplotlib.pyplot as a
import numpy as np
import matplotlib

n = np.linspace(0, 10, 100)
beta = 0

def gamma(beta_):
    return (1 - beta_ ** 2) ** (-1 / 2)
def x_mærke(num):
    return [2 * np.cos(np.arctan(float(num))), 2 * np.sin(np.arctan(float(num)))]
def ct_mærke(num):
    return [2 * np.sin(np.arctan(float(num))), 2 * np.cos(np.arctan(float(num)))]
def zeta(beta_):
    return np.arctanh(beta_)
def ct_mærke_(x_, ct_, beta_):
    return ct_ * np.cosh(zeta(beta_)) - x_ * np.sinh(zeta(beta_))
def x_mærke_(x_, ct_, beta_):
    return x_ * np.cosh(zeta(beta_)) - ct_ * np.sinh(zeta(beta_))

def lorenz_trans(val=0):
    a.plot(n, n, color='yellow', label='Lys')
    a.arrow(0, 0, 8, 0, width=0.02, color='blue', label='x, ct')
    a.arrow(0, 0, 0, 8, width=0.02, color='blue')
    a.arrow(0, 0, 2 * 3 * 2 * x_mærke(val)[0], 2 * 3 * 2 * x_mærke(val)[1], width=0.02, color='red', label='x\',ct\'')
    a.arrow(0, 0, 2 * 3 * 2 * ct_mærke(val)[0], 2 * 3 * 2 * ct_mærke(val)[1], width=0.02, color='red')
            # Grid i mærkedesystem
    a.ylim([-0.2, 8])
    a.xlim([-0.2, 8])

            # vertikal
    a.plot([x_mærke_((1), (10), float(val)), x_mærke_((1), (-10), float(val))],
                   [ct_mærke_(1, -10, float(val)), ct_mærke_(1, 10, float(val))], color='gray', linestyle='dashed',
                   linewidth=0.75)
    a.plot([x_mærke_((2), (10), float(val)), x_mærke_((2), (-10), float(val))],
                   [ct_mærke_(2, -10, float(val)), ct_mærke_(2, 10, float(val))], color='gray', linestyle='dashed',
                   linewidth=0.75)
    a.plot([x_mærke_((3), (10), float(val)), x_mærke_((3), (-10), float(val))],
                   [ct_mærke_(3, -10, float(val)), ct_mærke_(3, 10, float(val))], color='gray', linestyle='dashed',
                   linewidth=0.75)
    a.plot([x_mærke_((4), (10), float(val)), x_mærke_((4), (-10), float(val))],
                   [ct_mærke_(4, -10, float(val)), ct_mærke_(4, 10, float(val))], color='gray', linestyle='dashed',
                   linewidth=0.75)
    a.plot([x_mærke_((5), (10), float(val)), x_mærke_((5), (-10), float(val))],
                   [ct_mærke_(5, -10, float(val)), ct_mærke_(5, 10, float(val))], color='gray', linestyle='dashed',
                   linewidth=0.75)
    a.plot([x_mærke_((6), (10), float(val)), x_mærke_((6), (-10), float(val))],
                   [ct_mærke_(6, -10, float(val)), ct_mærke_(6, 10, float(val))], color='gray', linestyle='dashed',
                   linewidth=0.75)
    a.plot([x_mærke_((7), (10), float(val)), x_mærke_((7), (-10), float(val))],
                   [ct_mærke_(7, -10, float(val)), ct_mærke_(7, 10, float(val))], color='gray', linestyle='dashed',
                   linewidth=0.75)
            # horizontal
    a.plot([ct_mærke_(1, -10, float(val)), ct_mærke_(1, 10, float(val))],
                   [x_mærke_((1), (10), float(val)), x_mærke_((1), (-10), float(val))], color='gray',
                   linestyle='dashed', linewidth=0.75)
    a.plot([ct_mærke_(2, -10, float(val)), ct_mærke_(2, 10, float(val))],
                   [x_mærke_((2), (10), float(val)), x_mærke_((2), (-10), float(val))], color='gray',
                   linestyle='dashed', linewidth=0.75)
    a.plot([ct_mærke_(3, -10, float(val)), ct_mærke_(3, 10, float(val))],
                   [x_mærke_((3), (10), float(val)), x_mærke_((3), (-10), float(val))], color='gray',
                   linestyle='dashed', linewidth=0.75)
    a.plot([ct_mærke_(4, -10, float(val)), ct_mærke_(4, 10, float(val))],
                   [x_mærke_((4), (10), float(val)), x_mærke_((4), (-10), float(val))], color='gray',
                   linestyle='dashed', linewidth=0.75)
    a.plot([ct_mærke_(5, -10, float(val)), ct_mærke_(5, 10, float(val))],
                   [x_mærke_((5), (10), float(val)), x_mærke_((5), (-10), float(val))], color='gray',
                   linestyle='dashed', linewidth=0.75)
    a.plot([ct_mærke_(6, -10, float(val)), ct_mærke_(6, 10, float(val))],
                   [x_mærke_((6), (10), float(val)), x_mærke_((6), (-10), float(val))], color='gray',
                   linestyle='dashed', linewidth=0.75)
    a.plot([ct_mærke_(7, -10, float(val)), ct_mærke_(7, 10, float(val))],
                   [x_mærke_((7), (10), float(val)), x_mærke_((7), (-10), float(val))], color='gray',
                   linestyle='dashed', linewidth=0.75)
    a.legend()
    a.grid()
    a.show()

widgets.interact(lorenz_trans  , val=(0, 1, 0.01));
# Out:
# interactive(children=(FloatSlider(value=0.0, description='val', max=1.0, step=0.01), Output()), _dom_classes=(…
